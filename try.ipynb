# %%
import numpy as np 
from data_plot_utility import LSPlotter
from data_plot_utility import PremadeFunctions
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(["science","notebook","grid"])

# %%
X = np.linspace(-15,23,200)
y = 6*np.exp(-(X-5)**2/7) + 0.01*np.random.randn(X.size)

# %%
fig,ax = plt.subplots(1,1)
res,fit_func = LSPlotter.fit_and_plot(
  X,
  y,
  beta0=[1,1,1],
  fit_func=PremadeFunctions.func_gaussian,
  fig=fig,ax=ax,
  beta_names=["a","b","c"],
  latex = "$a e^{(x-b)^2/2c^2}$",
  ms=5)
